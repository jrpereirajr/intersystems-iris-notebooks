# %% [markdown]
# # Installation

# %% [markdown]
# ## IRIS Native SDK/DB-API instalation

# %%
import requests
url = 'https://github.com/intersystems-community/iris-driver-distribution/blob/main/DB-API/intersystems_irispython-3.2.0-py3-none-any.whl?raw=true'
r = requests.get(url, allow_redirects=True)
open('intersystems_irispython-3.2.0-py3-none-any.whl', 'wb').write(r.content)
# Out:
# 104198

# %%
# !dir *.whl
# Out:
#  O volume na unidade C ‚ Windows-SSD
#  O N£mero de S‚rie do Volume ‚ E4DB-7151
#
#  Pasta de C:\Users\jrper\dev\notebooks
#
# 06/10/2023  17:59           104.198 intersystems_irispython-3.2.0-py3-none-any.whl
#                1 arquivo(s)        104.198 bytes
#                0 pasta(s)   87.137.366.016 bytes dispon¡veis

# %%
# !pip install --force-reinstall ./intersystems_irispython-3.2.0-py3-none-any.whl
# Out:
# Processing c:\users\jrper\dev\notebooks\intersystems_irispython-3.2.0-py3-none-any.whl
# Installing collected packages: intersystems-irispython
#   Attempting uninstall: intersystems-irispython
#     Found existing installation: intersystems-irispython 3.2.0
#     Uninstalling intersystems-irispython-3.2.0:
#       Successfully uninstalled intersystems-irispython-3.2.0
# Successfully installed intersystems-irispython-3.2.0

# %% [markdown]
# ## Other libs

# %%
# !pip install pandas sqlalchemy-iris
# Out:
# Requirement already satisfied: pandas in c:\users\jrper\dev\venv\lib\site-packages (2.1.1)
# Requirement already satisfied: sqlalchemy-iris in c:\users\jrper\dev\venv\lib\site-packages (0.10.5)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\jrper\dev\venv\lib\site-packages (from pandas) (1.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jrper\dev\venv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jrper\dev\venv\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\jrper\dev\venv\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: SQLAlchemy>=1.3 in c:\users\jrper\dev\venv\lib\site-packages (from sqlalchemy-iris) (2.0.21)
# Requirement already satisfied: six>=1.5 in c:\users\jrper\dev\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\jrper\dev\venv\lib\site-packages (from SQLAlchemy>=1.3->sqlalchemy-iris) (4.8.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\jrper\dev\venv\lib\site-packages (from SQLAlchemy>=1.3->sqlalchemy-iris) (3.0.0)

# %% [markdown]
# # IRIS connection

# %%
import iris
from sqlalchemy import create_engine, text, DateTime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# InterSystems IRIS Cloud SQL connection parameters
args = {
    'hostname': 'k8s-edd597cb-ad527141-095ae65d0a-19cfc60bbd8e8170.elb.us-east-1.amazonaws.com', 
    'port': 1972,
    'namespace': 'USER', 
    'username': 'SQLAdmin', 
    'password': 'q-2DKfLyKtM!'
}

# %%
# !setx ISC_CLOUD_SQL_USER "SQLAdmin"
# Out:
# ÒXITO: o valor especificado foi salvo.

# %%
import getpass
username = getpass.getuser()
password = getpass.getpass("Enter your password")
print('Your username is: ' + username)
print('Your password is: ' + password)
# Out:
# Enter your password ········
# Your username is: jrper
# Your password is: ldasd

# %%
import os
os.getenv("ISC_CLOUD_SQL_USER")

# %%
# Create a sqlalchemy connection to IRIS
engine = create_engine(f"iris://{args['username']}:{args['password']}@{args['hostname']}:{args['port']}/{args['namespace']}")
conn = engine.connect()
# Out:
# C:\Users\jrper\dev\venv\Lib\site-packages\sqlalchemy_iris\base.py:888: SAWarning: There are no access to %Dictionary, may be required for some advanced features, such as Calculated fields, and include columns in indexes
#   util.warn(

# %% [markdown]
# # Data ingestion

# %%
# # Download the trainning dataset
# dataset_url = "https://data.cityofnewyork.us/api/views/kxp8-n2sj/rows.csv?accessType=DOWNLOAD"
# r = requests.get(url, allow_redirects=True)
# open('yellow_tripdata_15k.csv', 'wb').write(r.content)

# %%
# Load the trainning dataset from the CSV file, enforcing pandas to interpret columns tpep_pickup_datetime and tpep_dropoff_datetime as timestramp
train_df = pd.read_csv(
    "./yellow_tripdata_15k-train.csv", 
    parse_dates=[1,2]
)
train_df
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             2  2022-06-06 23:01:00   2022-06-06 23:11:00                1
# 1             1  2022-06-06 16:20:00   2022-06-06 16:25:00                1
# 2             1  2022-06-05 17:08:00   2022-06-05 17:24:00                1
# 3             2  2022-06-09 09:33:00   2022-06-09 09:54:00                2
# 4             1  2022-06-01 11:22:00   2022-06-01 11:22:00                1
# ...         ...                  ...                   ...              ...
# 15271         2  2022-06-03 09:54:00   2022-06-03 10:06:00                1
# 15272         2  2022-06-01 12:39:00   2022-06-01 13:03:00                1
# 15273         2  2022-06-03 11:25:00   2022-06-03 11:40:00                1
# 15274         2  2022-06-08 19:22:00   2022-06-08 19:27:00                1
# 15275         1  2022-06-05 20:23:00   2022-06-05 20:45:00                1
#
#        trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0               2.22           1                  N           164
# 1               0.90           1                  N           239
# 2               2.40           1                  N           229
# 3               3.65           1                  N           142
# 4               0.00           1                  N           145
# ...              ...         ...                ...           ...
# 15271           1.55           1                  N           186
# 15272           2.57           1                  N           233
# 15273           1.74           1                  N           186
# 15274           0.77           1                  N           162
# 15275           7.20           1                  N           138
#
#        DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0               211             1          9.5   0.50      0.5        2.66
# 1               239             2          5.5   3.50      0.5        0.00
# 2               143             2         12.5   2.50      0.5        0.00
# 3               249             1         16.0   0.00      0.5        2.00
# 4               145             2          2.5   0.00      0.5        0.00
# ...             ...           ...          ...    ...      ...         ...
# 15271           137             2          9.5   0.00      0.5        0.00
# 15272           142             1         15.5   0.00      0.5        3.76
# 15273            50             1         11.0   0.00      0.5        2.86
# 15274           107             2          5.0   1.00      0.5        0.00
# 15275           152             2         23.0   1.75      0.5        0.00
#
#        tolls_amount  improvement_surcharge  total_amount  \
# 0              0.00                    0.3         15.96
# 1              0.00                    0.3          9.80
# 2              0.00                    0.3         15.80
# 3              0.00                    0.3         21.30
# 4              0.00                    0.3          3.30
# ...             ...                    ...           ...
# 15271          0.00                    0.3         12.80
# 15272          0.00                    0.3         22.56
# 15273          0.00                    0.3         17.16
# 15274          0.00                    0.3          9.30
# 15275          6.55                    0.3         32.10
#
#        congestion_surcharge  airport_fee
# 0                       2.5         0.00
# 1                       2.5         0.00
# 2                       2.5         0.00
# 3                       2.5         0.00
# 4                       0.0         0.00
# ...                     ...          ...
# 15271                   2.5         0.00
# 15272                   2.5         0.00
# 15273                   2.5         0.00
# 15274                   2.5         0.00
# 15275                   0.0         1.25
#
# [15276 rows x 19 columns]

# %%
# Uses the sqlalchmey connection to create a table in InterSystems IRIS Cloud SQL and ingest the training dataset
train_df.to_sql(
    name='yellow_tripdata_train', # the table name that is going to be created in IRIS
    con=conn, 
    if_exists='replace', 
    index=False
)
# Out:
# -1

# %%
# Check how many records was ingested in IRIS database
# Note the use of the default IRIS schema SQLUser, 
# as we didn't define a schema when ingesting the dataset into a table in IRIS
sql_query = f"""
SELECT count(*) from SQLUser.yellow_tripdata_train
"""
result = conn.execute(text(sql_query))
print(f"Imported {result.first()[0]} results")
# Out:
# Imported 15276 results

# %%
# Retrive the first and last 5 records from the trainning dataset ingested in IRIS
sql = f"""
select top 5 * from SQLUser.yellow_tripdata_train order by ID
union
select top 5 * from SQLUser.yellow_tripdata_train order by ID desc
"""
pd.read_sql(sql, conn)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2022-06-06 23:01:00   2022-06-06 23:11:00                1
# 1         1  2022-06-06 16:20:00   2022-06-06 16:25:00                1
# 2         1  2022-06-05 17:08:00   2022-06-05 17:24:00                1
# 3         2  2022-06-09 09:33:00   2022-06-09 09:54:00                2
# 4         1  2022-06-01 11:22:00   2022-06-01 11:22:00                1
# 5         1  2022-06-05 20:23:00   2022-06-05 20:45:00                1
# 6         2  2022-06-08 19:22:00   2022-06-08 19:27:00                1
# 7         2  2022-06-03 11:25:00   2022-06-03 11:40:00                1
# 8         2  2022-06-01 12:39:00   2022-06-01 13:03:00                1
# 9         2  2022-06-03 09:54:00   2022-06-03 10:06:00                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.22           1                  N           164           211
# 1           0.90           1                  N           239           239
# 2           2.40           1                  N           229           143
# 3           3.65           1                  N           142           249
# 4           0.00           1                  N           145           145
# 5           7.20           1                  N           138           152
# 6           0.77           1                  N           162           107
# 7           1.74           1                  N           186            50
# 8           2.57           1                  N           233           142
# 9           1.55           1                  N           186           137
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1          9.5   0.50      0.5        2.66          0.00
# 1             2          5.5   3.50      0.5        0.00          0.00
# 2             2         12.5   2.50      0.5        0.00          0.00
# 3             1         16.0   0.00      0.5        2.00          0.00
# 4             2          2.5   0.00      0.5        0.00          0.00
# 5             2         23.0   1.75      0.5        0.00          6.55
# 6             2          5.0   1.00      0.5        0.00          0.00
# 7             1         11.0   0.00      0.5        2.86          0.00
# 8             1         15.5   0.00      0.5        3.76          0.00
# 9             2          9.5   0.00      0.5        0.00          0.00
#
#    improvement_surcharge  total_amount  congestion_surcharge  airport_fee
# 0                    0.3         15.96                   2.5         0.00
# 1                    0.3          9.80                   2.5         0.00
# 2                    0.3         15.80                   2.5         0.00
# 3                    0.3         21.30                   2.5         0.00
# 4                    0.3          3.30                   0.0         0.00
# 5                    0.3         32.10                   0.0         1.25
# 6                    0.3          9.30                   2.5         0.00
# 7                    0.3         17.16                   2.5         0.00
# 8                    0.3         22.56                   2.5         0.00
# 9                    0.3         12.80                   2.5         0.00

# %%
# Load the validation dataset from the CSV file
validate_df = pd.read_csv(
    "./yellow_tripdata_15k-validate.csv", 
    parse_dates=[1,2]
)
validate_df
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             2  2022-06-04 17:56:00   2022-06-04 18:56:00                1
# 1             1  2022-06-01 20:31:00   2022-06-01 20:50:00                1
# 2             2  2022-06-08 23:54:00   2022-06-09 00:04:00                4
# 3             2  2022-06-02 17:14:00   2022-06-02 17:17:00                2
# 4             1  2022-06-03 06:11:00   2022-06-03 06:21:00                1
# ...         ...                  ...                   ...              ...
# 15632         1  2022-06-01 07:23:00   2022-06-01 07:30:00                1
# 15633         2  2022-06-08 15:56:00   2022-06-08 16:08:00                1
# 15634         2  2022-06-08 15:21:00   2022-06-08 15:46:00                1
# 15635         1  2022-06-04 01:18:00   2022-06-04 01:23:00                1
# 15636         2  2022-06-08 14:57:00   2022-06-08 15:09:00                1
#
#        trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0              21.77           2                  N           132
# 1               3.00           1                  N           236
# 2               3.41           1                  N           140
# 3               0.32           1                  N           239
# 4               2.30           1                  N           142
# ...              ...         ...                ...           ...
# 15632           0.90           1                  N           162
# 15633           1.57           1                  N           234
# 15634           3.80           1                  N            45
# 15635           1.60           1                  N           229
# 15636           1.48           1                  N           236
#
#        DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0               142             4        -52.0    0.0     -0.5        0.00
# 1               100             2         14.0    3.0      0.5        0.00
# 2               234             2         12.0    0.5      0.5        0.00
# 3               239             1          4.0    1.0      0.5        2.00
# 4               162             2          9.0    2.5      0.5        0.00
# ...             ...           ...          ...    ...      ...         ...
# 15632           230             2          6.5    2.5      0.5        0.00
# 15633           186             1          9.0    0.0      0.5        2.46
# 15634           162             1         18.0    0.0      0.5        4.26
# 15635           141             1          6.5    3.0      0.5        2.05
# 15636           237             1          9.5    0.0      0.5        2.56
#
#        tolls_amount  improvement_surcharge  total_amount  \
# 0             -6.55                   -0.3        -63.10
# 1              0.00                    0.3         17.80
# 2              0.00                    0.3         15.80
# 3              0.00                    0.3         10.30
# 4              0.00                    0.3         12.30
# ...             ...                    ...           ...
# 15632          0.00                    0.3          9.80
# 15633          0.00                    0.3         14.76
# 15634          0.00                    0.3         25.56
# 15635          0.00                    0.3         12.35
# 15636          0.00                    0.3         15.36
#
#        congestion_surcharge  airport_fee
# 0                      -2.5        -1.25
# 1                       2.5         0.00
# 2                       2.5         0.00
# 3                       2.5         0.00
# 4                       2.5         0.00
# ...                     ...          ...
# 15632                   2.5         0.00
# 15633                   2.5         0.00
# 15634                   2.5         0.00
# 15635                   2.5         0.00
# 15636                   2.5         0.00
#
# [15637 rows x 19 columns]

# %%
# Ingest the validating dataset into InterSystems IRIS Cloud SQL
validate_df.to_sql(
    name='yellow_tripdata_validate', # the table name that is going to be created in IRIS
    con=conn, 
    if_exists='replace', 
    index=False)
# Out:
# -1

# %%
# Check how many records was ingested in IRIS database
sql_query = f"""
SELECT count(*) from SQLUser.yellow_tripdata_validate
"""
result = conn.execute(text(sql_query))
print(f"Imported {result.first()[0]} results")
# Out:
# Imported 15637 results

# %%
# Retrive the first and last 5 records from the validation dataset ingested in IRIS
sql = f"""
SELECT top 5 * from SQLUser.yellow_tripdata_validate order by ID
union
SELECT top 5 * from SQLUser.yellow_tripdata_validate order by ID desc
"""
pd.read_sql(sql, conn)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2022-06-04 17:56:00   2022-06-04 18:56:00                1
# 1         1  2022-06-01 20:31:00   2022-06-01 20:50:00                1
# 2         2  2022-06-08 23:54:00   2022-06-09 00:04:00                4
# 3         2  2022-06-02 17:14:00   2022-06-02 17:17:00                2
# 4         1  2022-06-03 06:11:00   2022-06-03 06:21:00                1
# 5         2  2022-06-08 14:57:00   2022-06-08 15:09:00                1
# 6         1  2022-06-04 01:18:00   2022-06-04 01:23:00                1
# 7         2  2022-06-08 15:21:00   2022-06-08 15:46:00                1
# 8         2  2022-06-08 15:56:00   2022-06-08 16:08:00                1
# 9         1  2022-06-01 07:23:00   2022-06-01 07:30:00                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0          21.77           2                  N           132           142
# 1           3.00           1                  N           236           100
# 2           3.41           1                  N           140           234
# 3           0.32           1                  N           239           239
# 4           2.30           1                  N           142           162
# 5           1.48           1                  N           236           237
# 6           1.60           1                  N           229           141
# 7           3.80           1                  N            45           162
# 8           1.57           1                  N           234           186
# 9           0.90           1                  N           162           230
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             4        -52.0    0.0     -0.5        0.00         -6.55
# 1             2         14.0    3.0      0.5        0.00          0.00
# 2             2         12.0    0.5      0.5        0.00          0.00
# 3             1          4.0    1.0      0.5        2.00          0.00
# 4             2          9.0    2.5      0.5        0.00          0.00
# 5             1          9.5    0.0      0.5        2.56          0.00
# 6             1          6.5    3.0      0.5        2.05          0.00
# 7             1         18.0    0.0      0.5        4.26          0.00
# 8             1          9.0    0.0      0.5        2.46          0.00
# 9             2          6.5    2.5      0.5        0.00          0.00
#
#    improvement_surcharge  total_amount  congestion_surcharge  airport_fee
# 0                   -0.3        -63.10                  -2.5        -1.25
# 1                    0.3         17.80                   2.5         0.00
# 2                    0.3         15.80                   2.5         0.00
# 3                    0.3         10.30                   2.5         0.00
# 4                    0.3         12.30                   2.5         0.00
# 5                    0.3         15.36                   2.5         0.00
# 6                    0.3         12.35                   2.5         0.00
# 7                    0.3         25.56                   2.5         0.00
# 8                    0.3         14.76                   2.5         0.00
# 9                    0.3          9.80                   2.5         0.00

# %% [markdown]
# # Create your model

# %%
# Make sure that there is no previous ML model in IRIS called TipPrediction
sql = """
drop model TipPrediction
"""
try:
    result = conn.execute(text(sql))
    print("Model removed.")
except:
    print("Can't drop the model - probably it doesn't exist.")
# Out:
# Model removed.

# %%
# Tells IRIS to create a ML model called 'TipPrediction' to predict the value of the target column 'tip_amount', 
# based on features (columns) within the training table 'SQLUser.yellow_tripdata_train'.
# For more information: https://docs.intersystems.com/irislatest/csp/docbook/DocBook.UI.Page.cls?KEY=GIML_Basics#GIML_Basics_Create
sql = """
create model TipPrediction predicting (tip_amount FLOAT) from SQLUser.yellow_tripdata_train
"""
conn.execute(text(sql))

# %%
# Get the ML models hosted in IRIS
# For more information: https://docs.intersystems.com/irislatest/csp/docbook/DocBook.UI.Page.cls?KEY=GIML_Maintain#GIML_Using_Maintain_View_Models
sql = """
select * from INFORMATION_SCHEMA.ML_MODELS
"""
pd.read_sql(sql, conn)
# Out:
#       MODEL_NAME                                        DESCRIPTION  \
# 0  TipPrediction  Model TipPrediction created via SQL by user SQ...
#
#   PREDICTING_COLUMN_NAME PREDICTING_COLUMN_TYPE  \
# 0             tip_amount                 DOUBLE
#
#                                         WITH_COLUMNS         CREATE_TIMESTAMP  \
# 0  VendorID:BIGINT, tpep_pickup_datetime:TIMESTAM...  2023-10-06 21:00:20.223
#
#   DEFAULT_TRAINED_MODEL_NAME DEFAULT_SETTINGS  \
# 0                       None             None
#
#                            DEFAULT_TRAINING_QUERY
# 0  SELECT * FROM  SQLUser . yellow_tripdata_train

# %% [markdown]
# # Train your model

# %%
# Let IRIS train the TipPrediction ML model using the tranning dataset SQLUser.yellow_tripdata_train 
# and label it as TipPredictionTranined
# For more information: https://docs.intersystems.com/irislatest/csp/docbook/DocBook.UI.Page.cls?KEY=GIML_Basics#GIML_Basics_Train
sql = """
train model TipPrediction as TipPredictionTranined
"""
conn.execute(text(sql))

# %%
# Get information about trannings performed by IRIS in thier ML models
# Note that IRIS used the H2O ML services as ML provider
# For more information: https://docs.intersystems.com/irislatest/csp/docbook/DocBook.UI.Page.cls?KEY=GIML_Maintain#GIML_Using_Maintain_View_TrainedModels
sql = """
select * from INFORMATION_SCHEMA.ML_TRAINED_MODELS
"""
result = conn.execute(text(sql))
pd.read_sql(sql, conn)
# Out:
#       MODEL_NAME     TRAINED_MODEL_NAME PROVIDER        TRAINED_TIMESTAMP  \
# 0  TipPrediction  TipPredictionTranined      H2O  2023-10-06 21:02:28.726
#
#    MODEL_TYPE MODEL_INFO
# 0  regression       None

# %%
# Get detailed information about trannings performed by IRIS in thier ML models
# For more information: https://docs.intersystems.com/irislatest/csp/docbook/DocBook.UI.Page.cls?KEY=GIML_Maintain#GIML_Using_Maintain_View_TrainingRuns
sql = """
select * from INFORMATION_SCHEMA.ML_TRAINING_RUNS
"""
pd.read_sql(sql, conn)
# Out:
#       MODEL_NAME      TRAINING_RUN_NAME PROVIDER          START_TIMESTAMP  \
# 0  TipPrediction  TipPredictionTranined      H2O  2023-10-06 21:00:20.919
#
#        COMPLETED_TIMESTAMP  TRAINING_DURATION RUN_STATUS STATUS_CODE  \
# 0  2023-10-06 21:02:28.726            127.807  completed           1
#
#                                                  LOG SETTINGS  \
# 0  2023-10-06 21:00:20.922 Starting Training for ...     None
#
#   ML_CONFIGURATION_NAME                              TRAINING_RUN_QUERY
# 0                  %H2O  SELECT * FROM  SQLUser . yellow_tripdata_train

# %% [markdown]
# # Validate your model

# %%
# Tells to IRIS to run the trained modlel TipPredictionTranined using the validation 
# dataset SQLUser.yellow_tripdata_validate in order to collect the performance metrics
# For more information: https://docs.intersystems.com/irislatest/csp/docbook/DocBook.UI.Page.cls?KEY=GIML_Basics#GIML_Basics_Validate
sql = """
validate model TipPrediction use TipPredictionTranined from SQLUser.yellow_tripdata_validate
"""
conn.execute(text(sql))

# %%
# Get genereal information about the validations executed by IRIS in their hosted ML models
# For more information: https://docs.intersystems.com/irislatest/csp/docbook/DocBook.UI.Page.cls?KEY=GIML_Maintain#GIML_Using_Maintain_View_ValidationRuns
sql = """
select * from INFORMATION_SCHEMA.ML_VALIDATION_RUNS
"""
pd.read_sql(sql, conn)
# Out:
#       MODEL_NAME     TRAINED_MODEL_NAME       VALIDATION_RUN_NAME  \
# 0  TipPrediction  TipPredictionTranined  TipPredictionTranined_v1
#
#            START_TIMESTAMP      COMPLETED_TIMESTAMP  VALIDATION_DURATION  \
# 0  2023-10-06 21:02:30.658  2023-10-06 21:02:32.811                2.153
#
#   RUN_STATUS STATUS_CODE                                                LOG  \
# 0  completed           1  2023-10-06 21:02:30.658: Preparing validation ...
#
#   SETTINGS                               VALIDATION_RUN_QUERY
# 0     None  SELECT tip_amount,VendorID,tpep_pickup_datetim...

# %%
# Get the value of performance metrics of validations executed by IRIS
# For more information: https://docs.intersystems.com/irislatest/csp/docbook/DocBook.UI.Page.cls?KEY=GIML_Maintain#GIML_Using_Maintain_View_ValidationMetrics
sql = """
select * from INFORMATION_SCHEMA.ML_VALIDATION_METRICS
"""
pd.read_sql(sql, conn)
# Out:
#       MODEL_NAME     TRAINED_MODEL_NAME       VALIDATION_RUN_NAME METRIC_NAME  \
# 0  TipPrediction  TipPredictionTranined  TipPredictionTranined_v1         MSE
# 1  TipPrediction  TipPredictionTranined  TipPredictionTranined_v1        RMSE
# 2  TipPrediction  TipPredictionTranined  TipPredictionTranined_v1    Variance
# 3  TipPrediction  TipPredictionTranined  TipPredictionTranined_v1          R2
#
#    METRIC_VALUE TARGET_VALUE
# 0          0.38         None
# 1          0.61         None
# 2          9.83         None
# 3          0.96         None

# %% [markdown]
# # Make predictions

# %%
# Use the predict() function to execute prediction using the ML model TipPredictionTranined
# This function automatically retrieves all need model features from the columns available 
# in the query - only the table SQLUser.yellow_tripdata_validate in this case
# For more information: https://docs.intersystems.com/irislatest/csp/docbook/DocBook.UI.Page.cls?KEY=GIML_Basics#GIML_Basics_Predict
sql = """
select 
      top 100
      predict(TipPrediction use TipPredictionTranined) as prediction, 
      tip_amount, 
      * 
    from
      SQLUser.yellow_tripdata_validate
"""
pd.read_sql(sql, conn)
# Out:
#               prediction  tip_amount  VendorID tpep_pickup_datetime  \
# 0    -0.1346211329017089        0.00         2  2022-06-04 17:56:00
# 1   -0.21182217128256917        0.00         1  2022-06-01 20:31:00
# 2   -0.17694538661249531        0.00         2  2022-06-08 23:54:00
# 3     1.8812803701508687        2.00         2  2022-06-02 17:14:00
# 4   -0.25757095483847003        0.00         1  2022-06-03 06:11:00
# ..                   ...         ...       ...                  ...
# 95    1.8674266708459124        2.00         2  2022-06-05 11:46:00
# 96    2.8385619037571113        2.86         2  2022-06-08 10:58:00
# 97     2.880945070420249        2.86         2  2022-06-09 10:16:00
# 98     4.069602625777027        4.44         2  2022-06-09 14:39:00
# 99    1.9486196682617118        1.96         2  2022-06-03 08:40:00
#
#    tpep_dropoff_datetime  passenger_count  trip_distance  RatecodeID  \
# 0    2022-06-04 18:56:00                1          21.77           2
# 1    2022-06-01 20:50:00                1           3.00           1
# 2    2022-06-09 00:04:00                4           3.41           1
# 3    2022-06-02 17:17:00                2           0.32           1
# 4    2022-06-03 06:21:00                1           2.30           1
# ..                   ...              ...            ...         ...
# 95   2022-06-05 11:52:00                1           0.81           1
# 96   2022-06-08 11:14:00                1           1.44           1
# 97   2022-06-09 10:32:00                1           2.03           1
# 98   2022-06-09 14:55:00                1           1.99           1
# 99   2022-06-03 08:47:00                2           1.09           1
#
#    store_and_fwd_flag  PULocationID  ...  payment_type  fare_amount  extra  \
# 0                   N           132  ...             4        -52.0    0.0
# 1                   N           236  ...             2         14.0    3.0
# 2                   N           140  ...             2         12.0    0.5
# 3                   N           239  ...             1          4.0    1.0
# 4                   N           142  ...             2          9.0    2.5
# ..                ...           ...  ...           ...          ...    ...
# 95                  N           234  ...             1          5.5    0.0
# 96                  N            48  ...             1         11.0    0.0
# 97                  N             4  ...             1         11.0    0.0
# 98                  N           162  ...             1         11.5    0.0
# 99                  N           186  ...             1          6.5    0.0
#
#     mta_tax  tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0      -0.5        0.00         -6.55                   -0.3        -63.10
# 1       0.5        0.00          0.00                    0.3         17.80
# 2       0.5        0.00          0.00                    0.3         15.80
# 3       0.5        2.00          0.00                    0.3         10.30
# 4       0.5        0.00          0.00                    0.3         12.30
# ..      ...         ...           ...                    ...           ...
# 95      0.5        2.00          0.00                    0.3         10.80
# 96      0.5        2.86          0.00                    0.3         17.16
# 97      0.5        2.86          0.00                    0.3         17.16
# 98      0.5        4.44          0.00                    0.3         19.24
# 99      0.5        1.96          0.00                    0.3         11.76
#
#     congestion_surcharge  airport_fee
# 0                   -2.5        -1.25
# 1                    2.5         0.00
# 2                    2.5         0.00
# 3                    2.5         0.00
# 4                    2.5         0.00
# ..                   ...          ...
# 95                   2.5         0.00
# 96                   2.5         0.00
# 97                   2.5         0.00
# 98                   2.5         0.00
# 99                   2.5         0.00
#
# [100 rows x 21 columns]

# %% [markdown]
# # Prediction vs actual chart

# %%
# Retrieves all predictions from the validation dataset in order to plot the 'Prediction vs Acutal' chart
sql = """
select 
      cast(predict(TipPrediction use TipPredictionTranined) as double) as prediction, 
      tip_amount
    from
      SQLUser.yellow_tripdata_validate
"""
result = conn.exec_driver_sql(sql)
y = []
predicted = []
for row in result:
    y.append(row[1])
    predicted.append(row[0])
y = np.asarray(y)
predicted = np.asarray(predicted)

# %%
# Plot the 'Prediction vs Acutal' chart
fig, ax = plt.subplots()
ax.scatter(predicted, y, edgecolors=(0, 0, 0))
ax.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=4)
ax.set_xlabel('Prediction')
ax.set_ylabel('Actual')
plt.show()

# %% [markdown]
# # Releasing resources

# %%
conn.close()
engine.dispose()

# %% [markdown]
# # References

# %% [markdown]
# https://docs.intersystems.com/irislatest/csp/docbook/DocBook.UI.Page.cls?KEY=BPYNAT_refapi#BPYNAT_refapi_irispackage_createconn
#
# https://community.intersystems.com/post/sqlalchemy-easiest-way-use-python-and-sql-iriss-databases
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_sql.html
#
# https://docs.intersystems.com/irislatest/csp/docbook/DocBook.UI.Page.cls?KEY=GIML
